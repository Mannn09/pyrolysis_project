# %%
import numpy as np

class Config:
    # Physical Properties
    K_THERM = 0.08
    RHO = 400.0
    CP = 1500.0
    R_GAS = 8.314

    # Kinetics (Rice Husk)
    W0 = {'M': 0.10, 'HC': 0.20, 'C': 0.35, 'L': 0.25}
    KINETICS_PARAMS = {
        'M':  [5.13e6, 40000, 2.8],
        'HC': [9.67e9, 126310, 2.3],
        'C':  [3.50e12, 168610, 1.38],
        'L':  [2.59e5, 87210, 1.51]
    }

    # Geometry
    R_MAX = 0.010
    Z_MAX = 0.030
    NR, NZ = 25, 50

    # Simulation
    HEATING_RATE = 60.0 # C/min
    T_INITIAL = 25.0
    DT = 1.0           # Seconds
    TOTAL_MIN = 10
    H_CONV = 60.0      # Heat transfer coeff
